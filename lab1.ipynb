# %% [markdown]
# # lab1

# %% [markdown]
# #this is my first lab.

# %%
import pandas as pd 

covid_data = pd.read_csv('s3://ia-340-2025-fall-lor-99771035/data.csv')

covid_data.head()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/fsspec/registry.py:298: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  14/12/2020   14     12  2020    746       6             Afghanistan    AF
# 1  13/12/2020   13     12  2020    298       9             Afghanistan    AF
# 2  12/12/2020   12     12  2020    113      11             Afghanistan    AF
# ...

# %%
crime_data = pd.read_csv('s3://ia-340-2025-fall-lor-99771035/Crime_Incidents_in_the_Last_30_Days.csv')

crime_data.head()
# Out:
#            X          Y       CCN              REPORT_DAT     SHIFT  METHOD  \
# 0  399215.87  138751.20  25079273  2025/08/11 17:39:31+00       DAY  OTHERS
# 1  398165.14  143984.58  25115828  2025/07/31 13:51:31+00       DAY  OTHERS
# 2  398432.56  138758.47  25115842  2025/07/31 13:28:51+00       DAY  OTHERS
# 3  396001.90  138485.84  25117524  2025/08/03 08:06:35+00  MIDNIGHT  OTHERS
# 4  398109.76  141981.47  25120116  2025/08/08 02:44:27+00   EVENING  OTHERS
#
#                OFFENSE                                       BLOCK     XBLOCK  \
# 0              ROBBERY   1800 - 2199 BLOCK OF NORTH CAPITOL STREET  399215.87
# 1         THEFT F/AUTO     500 - 699 BLOCK OF QUACKENBOS STREET NW  398165.14
# 2         THEFT F/AUTO              400 - 499 BLOCK OF U STREET NW  398432.56
# 3         THEFT F/AUTO  1800 - 1805 BLOCK OF CONNECTICUT AVENUE NW  396001.90
# 4  MOTOR VEHICLE THEFT          4500 - 4599 BLOCK OF 7TH STREET NW  398109.76
#
# ...
